# %%
import pandas as pd

file = "Historical logs/day_degrading_grip.csv"

df = pd.read_csv(file)

df
# Out:
#        Time     Light  Floor friction  Object friction  State
# 0         0  0.936450        0.443199         0.951844      0
# 1         5  0.936450        0.443199         0.951844      0
# 2        10  0.936450        0.443199         0.951844      0
# 3        15  0.936450        0.443199         0.951844      0
# 4        20  0.936450        0.443199         0.951844      0
# ...     ...       ...             ...              ...    ...
# 2474  11560  0.951887        0.441455         0.549287      0
# 2475  11564  0.951887        0.441455         0.549287      1
# 2476  11565  0.951887        0.441455         0.549287      1
# 2477  11570  0.951887        0.441455         0.549287      1
# 2478  11575  0.951887        0.441455         0.549287      1
#
# [2479 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

for i in range (1,len(df.columns)):
    plt.figure()
    plt.plot(df[df.columns[0]],df[df.columns[i]])

    # Add labels and title
    plt.xlabel(df.columns[0])
    plt.ylabel(df.columns[i])
    plt.title(f'Plot of {df.columns[0]} vs {df.columns[i]}')
    plt.show

# %%
import matplotlib.pyplot as plt

for i in range (1,len(df.columns)):
    plt.figure()
    plt.plot(df[df.columns[0]],df[df.columns[i]])

    # Add labels and title
    plt.xlabel(df.columns[0])
    plt.ylabel(df.columns[i])
    plt.title(f'Plot of {df.columns[0]} vs {df.columns[i]}')
    plt.show
